# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# forループで水～冥の9行を表示
for value in array:
  print(value)

# whileループで水～冥の9行を表示
i = 0
while i < 9:
  print(array[i])
  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
