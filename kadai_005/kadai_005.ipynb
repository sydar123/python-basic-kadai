# %%
top = 10            # 上辺
bottom = 20         # 下辺
height = 5          # 高さ
daikei_area = 0.0   # 台形の面積

daikei_area = (top + bottom) * height / 2

print(str(daikei_area) + "cm²")
# Out:
# 75.0cm²
